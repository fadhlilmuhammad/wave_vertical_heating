# %%
import xarray as xr
import numpy as np 
from pathlib import Path
import os 
import sys
import glob

# %%
folder = Path("/home/563/fm6730/localrepo/wave_vertical_heating/data/temp/wave_vertical_heating/q/era5")

# %%
files = sorted(glob.glob(f"{folder}/*.nc"))

# %%
ds = xr.open_mfdataset(files)

# %%
ds
# Out:
# <xarray.Dataset> Size: 14GB
# Dimensions:    (time: 15341, bnds: 2, level: 22, lat: 73, lon: 144)
# Coordinates:
#   * time       (time) datetime64[ns] 123kB 1979-01-01T11:00:00 ... 2020-12-31...
#   * level      (level) int32 88B 10 20 30 50 70 100 ... 800 850 900 925 950 1000
#   * lat        (lat) float64 584B -90.0 -87.5 -85.0 -82.5 ... 85.0 87.5 90.0
#   * lon        (lon) float64 1kB 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] 245kB dask.array<chunksize=(1, 2), meta=np.ndarray>
#     q          (time, level, lat, lon) float32 14GB dask.array<chunksize=(1, 1, 1, 144), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.6.0 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Wed Jul 01 14:31:47 2026: cdo remapcon,r144x73 /home/563/fm...
#     license:      Licence to use Copernicus Products: https://apps.ecmwf.int/...
#     summary:      ERA5 is the fifth generation ECMWF atmospheric reanalysis o...
#     title:        ERA5 pressure-levels oper specific_humidity 19790101-19790131
#     frequency:    day
#     CDO:          Climate Data Operators version 2.6.0 (https://mpimet.mpg.de...
