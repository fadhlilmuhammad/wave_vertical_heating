# %%
import xarray as xr 
import pandas as pd
import numpy as np 
from pathlib import Path

# %%
wave = "mjo"
var = "q1"
ens = "e01"

# %%
diri = Path(f"/home/563/fm6730/localrepo/wave_vertical_heating/data/derived/q1_vert_structure/filtered/{wave}")

# %%
files = [f for f in diri.iterdir() if f.is_file() and {var} in f.name and ]

# %%
files
# Out:
# [PosixPath('/home/563/fm6730/localrepo/wave_vertical_heating/data/derived/q1_vert_structure/filtered/mjo/mjo_mjo_tlag_da_q1_19950701_e03_remap_padded.nc'),
#  PosixPath('/home/563/fm6730/localrepo/wave_vertical_heating/data/derived/q1_vert_structure/filtered/mjo/mjo_mjo_tlag_da_q1_19850601_e02_remap_padded.nc'),
#  PosixPath('/home/563/fm6730/localrepo/wave_vertical_heating/data/derived/q1_vert_structure/filtered/mjo/mjo_mjo_tlag_da_q1_20080801_e01_remap_padded.nc'),
#  PosixPath('/home/563/fm6730/localrepo/wave_vertical_heating/data/derived/q1_vert_structure/filtered/mjo/mjo_mjo_tlag_da_q1_19880601_e01_remap_padded.nc'),
#  PosixPath('/home/563/fm6730/localrepo/wave_vertical_heating/data/derived/q1_vert_structure/filtered/mjo/mjo_mjo_tlag_da_q1_19920901_e01_remap_padded.nc'),
#  PosixPath('/home/563/fm6730/localrepo/wave_vertical_heating/data/derived/q1_vert_structure/filtered/mjo/mjo_mjo_tlag_da_q1_20060201_e01_remap_padded.nc'),
# ...
